# %%
# Run in Jupyter notebook
from groq import Groq
from dotenv import load_dotenv
import os
from qdrant_client import QdrantClient
from sentence_transformers import SentenceTransformer
import pypdf
from bs4 import BeautifulSoup

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %%
key = os.getenv("GROQ_API_KEY")
print(f"Key loaded: {key[:5]}...{key[-5:] if key else 'None'}") # Only prints start/end for safety
# Out:
# Key loaded: gsk_i...QOp4j

# %%
# Test Groq connection
load_dotenv()
groq_client = Groq(api_key=os.getenv("GROQ_API_KEY"))

response = groq_client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Say 'Setup complete!'"}],
    max_tokens=10
)

print(response.choices[0].message.content)
print(f"✅ Cost: $0.00 (FREE!)")
# Out:
# Setup complete!
# ✅ Cost: $0.00 (FREE!)

# %%
# Test Qdrant (local mode)
qdrant_client = QdrantClient()  # In-memory for testing
print("✅ Qdrant client created successfully!")
# Out:
# ✅ Qdrant client created successfully!

# %%
vars(qdrant_client._client)
# Out:
# {'_prefer_grpc': False,
#  '_grpc_port': 6334,
#  '_grpc_options': {'grpc.primary_user_agent': 'python-client/1.16.2 python/3.11.14'},
#  '_https': False,
#  '_scheme': 'http',
#  '_pool_size': None,
#  '_prefix': '',
#  '_host': 'localhost',
#  '_port': 6333,
#  '_api_key': None,
#  '_auth_token_provider': None,
#  '_grpc_headers': [],
#  '_rest_headers': {'User-Agent': 'python-client/1.16.2 python/3.11.14'},
#  '_grpc_compression': None,
#  'rest_uri': 'http://localhost:6333',
#  '_rest_args': {'headers': {'User-Agent': 'python-client/1.16.2 python/3.11.14'},
#   'http2': False,
#   'limits': Limits(max_connections=None, max_keepalive_connections=0, keepalive_expiry=5.0)},
#  '_timeout': 5,
#  'openapi_client': <qdrant_client.http.api_client.SyncApis at 0x1d7033d7750>,
#  '_grpc_channel_pool': [],
#  '_grpc_points_client_pool': None,
#  '_grpc_collections_client_pool': None,
#  '_grpc_snapshots_client_pool': None,
#  '_grpc_root_client_pool': None,
#  '_grpc_client_next_index': 0,
# ...
